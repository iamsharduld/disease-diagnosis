# %%
import numpy as np
import pandas as pd

# %%
# Non ML Approach
data = pd.read_csv('dataset/Code-H.csv')
data = data.drop(data.index[[0]])
cols = data.columns
cols = cols[:-2]
X = data[data.columns]
y = data['0Symptoms list']
X
# Out:
#      Sex Female Has Chills  ...      0Symptoms list Code disease
# 1             0          0  ...  Acute appendicitis          CD1
# 2             0          0  ...  Acute appendicitis          CD1
# 3             0          0  ...  Acute appendicitis          CD1
# 4             0          0  ...  Acute appendicitis          CD1
# 5             0          0  ...  Acute appendicitis          CD1
# ...         ...        ...  ...                 ...          ...
# 5579          0          1  ...   Vescicle calculus         CD72
# 5580          0          1  ...   Vescicle calculus         CD72
# 5581          0          1  ...   Vescicle calculus         CD72
# 5582          0          1  ...   Vescicle calculus         CD72
# 5583          0          1  ...   Vescicle calculus         CD72
#
# [5583 rows x 51 columns]

# %%
cols
# Out:
# Index(['Sex Female', 'Has Chills', 'Location -Localised or otherwise',
#        'Characteristic Sharp', 'Characteristic Colicky',
#        'Characteristic Burning', 'Characteristic Throbbing',
#        'Eating outside food', 'Started with spicy Food',
#        'Started with fatty meal', 'Started with Trauma',
#        'Started with Medicines like Diclofenac brufen erythromycin or Metrogyl',
#        'Started with Alcohol', 'Started Suddenly', 'Heartburn',
#        'Moves to upper abdomen on right side ',
#        'Moves to Lower abdomen on right side ', 'Moves to left',
#        'Moves to back ', 'Moves to Groin', 'Aggravated when one coughs',
#        'Relieved by Antacid', 'Appears IntermIttently',
#        'Limits movement/ normal breathing', 'Associated with loose motions',
#        'Associated with Constipation', 'Associated with Fever',
#        'Associated with distension', 'Associated with Jaundice',
# ...

# %%
# Code for Dataset Code-H
ip = ['Associated with Fever', 'Has Chills']
ip2 = ['Caries teeth']
testip = []
filtered = data

for symptom in ip:
    filtered = filtered.loc[(filtered[symptom] == "1")]

df = filtered.drop_duplicates(subset = ["0Symptoms list"])

diag = []

for row in df.itertuples():
    diag.append(row._50)
diag
# Out:
# ['Acute cholangitis',
#  'Acute colonic Diverticulitis with perforation',
#  'Malaria',
#  'Omphalitis',
#  'Pneumonia Basal',
#  'Pyonephrosis',
#  'UTI']

# %%
# Code for Dataset Code-J
# Non ML Approach
data = pd.read_csv('dataset/Code-J.csv')
data = data.drop(data.index[[0]])
cols = data.columns
cols = cols[2:]
X = data[data.columns]
y = data['0Symptoms list']
X
# Out:
#                     0Symptoms list  ... Blood and mucus in stool
# 1                 Appendix disease  ...                        0
# 2              Bile duct infection  ...                        0
# 3           Gall bladder infection  ...                        0
# 4     Colon Diverticulum Infection  ...                        2
# 5   Colon Diverticulum perforation  ...                        2
# 6                Ulcer exacerbated  ...                        0
# 7                  Gastroenteritis  ...                        2
# 8                  Acute Gastritis  ...                        0
# 9                        Hepatitis  ...                        0
# 10                    Pancreatitis  ...                        0
# 11                 Amoebic Colitis  ...                        1
# 12      Aorta dissection Emergency  ...                        0
# 13               Pus near Appendix  ...                        0
# ...

# %%
cols
# Out:
# Index(['Sex M', 'Sex Female', 'Chills', 'Pain Localised', 'Sharp pain',
#        'Colicky pain', 'Burning pain', 'Throbbing pain', 'Dining Out',
#        'Started with spicy meal', 'Started with oily meal',
#        'Started with Blunt Injury', 'Started after taking certain medicines',
#        'Started after Alcoholic drinks session', 'Started All of a sudden',
#        'Heartburn', 'Pain shifts near right ribcage',
#        'Pain Moves to Right Lower abdomen', 'Pain moves to left side',
#        'Pain moves to back', 'Pain moves to Groin',
#        'Pain is is increased if one coughs',
#        'Pain is relieved after taking antacids', 'Pain appears IntermIttently',
#        'Pain Limits movement', 'Pain Limits normal breathing', 'Loose motions',
#        'Constipation', 'Fever', 'Bloating', 'Jaundice', 'Urine red coloured',
#        'Burning urination', 'Headache', 'During MC periods',
#        'Past history of abdominal surgery', 'Hernia',
# ...

# %%
# Pandas Dataframe filtering option
ip = ['Loss of weight']
testip = []
filtered = data

for symptom in ip:
    filtered = filtered.loc[((filtered[symptom] == "1") | (filtered[symptom] == "2") )]

df = filtered.drop_duplicates(subset = ["0Symptoms list"])

diag = []

for row in df.itertuples():
    diag.append(row._1)
diag
# Out:
# ['Chronic Pancreatitis', 'Ileocaecal tuberculosis', 'Liver abscess']
